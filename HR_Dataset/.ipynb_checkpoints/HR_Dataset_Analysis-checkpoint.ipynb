# %%
import numpy as np
import pandas as pd
import seaborn as sns
import plotly.express as px
import warnings 
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
# %matplotlib.inline
# Out:
# UsageError: Line magic function `%matplotlib.inline` not found.

# %%
df = pd.read_csv('HRDataset_v14.csv')

# %%
df.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %%
df.columns
# Out:
# Index(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
#        'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID',
#        'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
#        'Sex', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
#        'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30',
#        'Absences'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Employee_Name                  object
# EmpID                           int64
# MarriedID                       int64
# MaritalStatusID                 int64
# GenderID                        int64
# EmpStatusID                     int64
# DeptID                          int64
# PerfScoreID                     int64
# FromDiversityJobFairID          int64
# Salary                          int64
# Termd                           int64
# PositionID                      int64
# Position                       object
# State                          object
# Zip                             int64
# DOB                            object
# Sex                            object
# MaritalDesc                    object
# CitizenDesc                    object
# HispanicLatino                 object
# RaceDesc                       object
# DateofHire                     object
# DateofTermination              object
# TermReason                     object
# EmploymentStatus               object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               311 non-null    object
#  1   EmpID                       311 non-null    int64
#  2   MarriedID                   311 non-null    int64
#  3   MaritalStatusID             311 non-null    int64
#  4   GenderID                    311 non-null    int64
#  5   EmpStatusID                 311 non-null    int64
#  6   DeptID                      311 non-null    int64
#  7   PerfScoreID                 311 non-null    int64
#  8   FromDiversityJobFairID      311 non-null    int64
#  9   Salary                      311 non-null    int64
#  10  Termd                       311 non-null    int64
#  11  PositionID                  311 non-null    int64
#  12  Position                    311 non-null    object
# ...

# %%
df.describe()
# Out:
#               EmpID   MarriedID  MaritalStatusID    GenderID  EmpStatusID  \
# count    311.000000  311.000000       311.000000  311.000000   311.000000
# mean   10156.000000    0.398714         0.810289    0.434084     2.392283
# std       89.922189    0.490423         0.943239    0.496435     1.794383
# min    10001.000000    0.000000         0.000000    0.000000     1.000000
# 25%    10078.500000    0.000000         0.000000    0.000000     1.000000
# 50%    10156.000000    0.000000         1.000000    0.000000     1.000000
# 75%    10233.500000    1.000000         1.000000    1.000000     5.000000
# max    10311.000000    1.000000         4.000000    1.000000     5.000000
#
#            DeptID  PerfScoreID  FromDiversityJobFairID         Salary  \
# count  311.000000   311.000000              311.000000     311.000000
# mean     4.610932     2.977492                0.093248   69020.684887
# std      1.083487     0.587072                0.291248   25156.636930
# ...

# %%
df.isnull().sum()
# Out:
# Employee_Name                   0
# EmpID                           0
# MarriedID                       0
# MaritalStatusID                 0
# GenderID                        0
# EmpStatusID                     0
# DeptID                          0
# PerfScoreID                     0
# FromDiversityJobFairID          0
# Salary                          0
# Termd                           0
# PositionID                      0
# Position                        0
# State                           0
# Zip                             0
# DOB                             0
# Sex                             0
# MaritalDesc                     0
# CitizenDesc                     0
# HispanicLatino                  0
# RaceDesc                        0
# DateofHire                      0
# DateofTermination             207
# TermReason                      0
# EmploymentStatus                0
# Department                      0
# ManagerName                     0
# ...

# %%
df[['DateofHire','DateofTermination']]
# Out:
#     DateofHire DateofTermination
# 0     7/5/2011               NaN
# 1    3/30/2015         6/16/2016
# 2     7/5/2011         9/24/2012
# 3     1/7/2008               NaN
# 4    7/11/2011          9/6/2016
# ..         ...               ...
# 306   7/7/2014               NaN
# 307   9/2/2008         9/29/2015
# 308  4/10/2010               NaN
# 309  3/30/2015               NaN
# 310  9/29/2014               NaN
#
# [311 rows x 2 columns]

# %%
i=0
while i<len(df.DateofTermination):
    if type(df['DateofTermination'][i])==float:
        df['DateofTermination'][i]=df['DateofHire'][i]
    i+=1

# %%
## Demographic Analysis

# %% [markdown]
# Gender Distribution: Analyze the proportion of male vs. female employees.

# %%
df.columns
# Out:
# Index(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
#        'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID',
#        'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
#        'Sex', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
#        'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30',
#        'Absences'],
#       dtype='object')

# %%
df.Sex.value_counts().plot(kind='bar',color=['green','purple'])
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title("proportion of male vs. female employees")
# Out:
# Text(0.5, 1.0, 'proportion of male vs. female employees')

# %% [markdown]
# Marital Status Distribution: Examine the marital status of employees to understand the diversity of marital backgrounds.

# %%
df.columns
# Out:
# Index(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
#        'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID',
#        'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
#        'Sex', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
#        'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30',
#        'Absences'],
#       dtype='object')

# %%
df[['MarriedID', 'MaritalStatusID','MaritalDesc']]
# Out:
#      MarriedID  MaritalStatusID MaritalDesc
# 0            0                0      Single
# 1            1                1     Married
# 2            1                1     Married
# 3            1                1     Married
# 4            0                2    Divorced
# ..         ...              ...         ...
# 306          0                0      Single
# 307          0                0      Single
# 308          0                0      Single
# 309          0                0      Single
# 310          0                4     Widowed
#
# [311 rows x 3 columns]

# %%
df.MarriedID.unique(),df.MaritalStatusID.unique(),df.MaritalDesc.unique()
# Out:
# (array([0, 1]),
#  array([0, 1, 2, 4, 3]),
#  array(['Single', 'Married', 'Divorced', 'Widowed', 'Separated'],
#        dtype=object))

# %%
sns.countplot(x='MaritalDesc',data = df,color='blue')
plt.xlabel('Marital Status')
plt.ylabel("Count")
plt.title("Marital status of employees")
plt.show()

# %% [markdown]
# Race and Ethnicity Distribution: Assess the racial and ethnic composition of the workforce to gauge diversity and inclusion efforts.

# %%
df.columns
# Out:
# Index(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
#        'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID',
#        'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
#        'Sex', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
#        'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30',
#        'Absences'],
#       dtype='object')

# %%
df['HispanicLatino']=df['HispanicLatino'].str.replace('No','no').str.replace('Yes','yes')

# %%
df['HispanicLatino'].value_counts()
# Out:
# HispanicLatino
# no     283
# yes     28
# Name: count, dtype: int64

# %%
sns.countplot(x='RaceDesc',hue='HispanicLatino',data =df,palette='rocket')
plt.xticks(rotation=90)
plt.xlabel("Race Description")
plt.ylabel("Count")
plt.title("Race and Ethnicity Distribution")
plt.show()

# %%
df['RaceDesc'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title('Race and Ethnicity Distribution')
plt.ylabel('')
plt.show()

# %% [markdown]
# Citizenship Status

# %%
df.columns
# Out:
# Index(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
#        'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID',
#        'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
#        'Sex', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
#        'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30',
#        'Absences'],
#       dtype='object')

# %%
df.CitizenDesc.value_counts().plot.pie(autopct='%1.1f%%',startangle=90,legend=True)
plt.title("Employee Citzens Distribution")
plt.show()

# %%
sns.countplot(x='CitizenDesc',data =df,palette='rocket')
plt.xlabel("Citizen Description")
plt.ylabel("Counts")
plt.title("Employee Citzens Distribution")
plt.show()

# %% [markdown]
# ### 2. Employee Satisfaction and Engagement

# %% [markdown]
# Employee Satisfaction

# %%
df.columns
# Out:
# Index(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
#        'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID',
#        'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
#        'Sex', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
#        'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30',
#        'Absences'],
#       dtype='object')

# %%
df.EmpSatisfaction.value_counts()
# Out:
# EmpSatisfaction
# 3    108
# 5     98
# 4     94
# 2      9
# 1      2
# Name: count, dtype: int64

# %%
sns.countplot(x='EmpSatisfaction',hue='Department',data = df)
plt.xlabel("Satisfaction Rating")
plt.ylabel('Count')
plt.title("Department wise Satisfaction of Employees")
plt.show()

# %%
sns.countplot(x='EmpSatisfaction',hue='Sex',data = df)
plt.xlabel("Satisfaction Rating")
plt.ylabel('Count')
plt.title("Gender wise Satisfaction of Employees")
plt.show()

# %%
sns.countplot(x='EmpSatisfaction',hue='CitizenDesc',data = df)
plt.xlabel("Satisfaction Rating")
plt.ylabel('Count')
plt.title("Citizen wise Satisfaction of Employees")
plt.show()

# %%
sns.countplot(x='EmpSatisfaction',hue='RaceDesc',data = df)
plt.xlabel("Satisfaction Rating")
plt.ylabel('Count')
plt.title("Citizen wise Satisfaction of Employees")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['EmpSatisfaction'], kde=True)
plt.title('Employee Satisfaction Levels')
plt.xlabel('Satisfaction Score')
plt.ylabel('Number of Employees')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='PerfScoreID', y='PerformanceScore', data=df)
plt.title('Performance Scores by Performance Rating')
plt.xlabel('Performance Rating')
plt.ylabel('Performance Score')
plt.show()
